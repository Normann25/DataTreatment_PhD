# %%
import numpy as np

# %%
def H_conc(K, c):
    d = K**2 + 4*c*K
    return (-K + np.sqrt(d)) / 2

# %% [markdown]
# Uge 5

# %%
# Opgave 2

print('a)')
H = H_conc(5.00*10**(-6), 0.02)
print(f'[H+] = {H} M')
pH = -np.log10(H)
print(f'pH = {pH}')

print('b)')
A = H
pOH = 14-pH
print(f'pOH = {pOH}')
OH = 10**(-pOH)
print(f'[OH-] = {OH} M')

print('c)')
A_after = (5.00*10**(-6)*0.02) / 0.20
print(f'[A-] = {A_after} M')
# Out:
# a)
# [H+] = 0.0003137376479801227 M
# pH = 3.5034333635815718
# b)
# pOH = 10.496566636418429
# [OH-] = 3.1873764798012224e-11 M
# c)
# [A-] = 5e-07 M

# %%
# Opgave 3

print('a)')
H = H_conc(4.5*10**(-4), 0.250)
print(f'[H+] = {H} M')
pH = -np.log10(H)
print(f'pH = {pH}')

print('b)')
Kb = 10**(-14) / (4.5*10**(-4))
print(f'Kb = {Kb}')
c_NaNO2 = 0.005 / 0.075
print(f'c(NaNO2) = {c_NaNO2} M')
OH = H_conc(Kb, c_NaNO2)
print(f'[OH-] = {OH} M')
pH = 14 + np.log10(OH)
print(f'pH = {pH}')
# Out:
# a)
# [H+] = 0.010383987934765504 M
# pH = 1.9836358251534718
# b)
# Kb = 2.222222222222222e-11
# c(NaNO2) = 0.06666666666666667 M
# [OH-] = 1.217150127839973e-06 M
# pH = 8.085344149036416

# %%
# Opgave 4

print('a)')
Delta_H = (-635 + (-394)) - (-1207)
print(f'Delta_H = {Delta_H} kJ/mol')
Delta_S = (40 + 214) - 89
print(f'Delta_S = {Delta_S} J/(mol*K)')

print('b)')
Delta_G = Delta_H - 298*Delta_S*10**(-3)
print(f'Delta_G = {Delta_G} kJ/mol')
K = np.exp(-Delta_G / (0.008314*298))
print(f'p = K = {K} bar')
# Out:
# a)
# Delta_H = 178 kJ/mol
# Delta_S = 165 J/(mol*K)
# b)
# Delta_G = 128.82999999999998 kJ/mol
# p = K = 2.61422659278265e-23 bar

# %% [markdown]
# Obligatorisk opgave 4

# %%
print('a)')
H = H_conc(1.8*10**(-5), 0.178)
print(f'[H+] = {H} M')
pH = -np.log10(H)
print(f'pH = {pH:.3f}')

print('c)')
c_syre = (0.025*0.178-0.035*0.125)/0.06
print(f'c(syre) = {c_syre} M')
c_base = (0.035*0.125)/0.06
print(f'c(base) = {c_base} M')
pH=4.74+np.log10(c_base/c_syre)
print(f'pH = {pH:.3f}')

print('a)')
OH = H_conc(5.75*10**(-10), 0.0734)
print(f'[OH-] = {OH} M')
pOH = -np.log10(OH)
print(f'pOH = {pOH:.3f}')
print(f'pH = {14-pOH}')
# Out:
# a)
# [H+] = 0.0017809946927295622 M
# pH = 2.749
# c)
# c(syre) = 0.0012499999999999924 M
# c(base) = 0.07291666666666667 M
# pH = 6.506
# a)
# [OH-] = 6.49625004569742e-06 M
# pOH = 5.187
# pH = 8.81266273288593

# %% [markdown]
# Obligatorisk opgave 5

# %%
print('opg. 3a)')
K=5.0*10**(10)*np.exp(-178000/(8.3145*310))
print(f'k = {K} s^-1')
t_half =np.log(2)/K
print(f't_1/2 = {t_half} s')

print('b)')
K=5.0*10**(10)*np.exp(-178000/(8.3145*673))
print(f'k = {K} s^-1')
# Out:
# opg. 3a)
# k = 5.092102846740929e-20 s^-1
# t_1/2 = 1.3612199152724822e+19 s
# b)
# k = 0.0007654191197123903 s^-1
