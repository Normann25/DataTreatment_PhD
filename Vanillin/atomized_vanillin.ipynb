# %%
import sys
sys.path.append('../')
from read_data_functions import *
from plot_functions import *
from calculations import *
plt.style.use('../Style.mplstyle')
import warnings
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None  # suppress warnings

# %%
path = '../../../Data/2026/260112_Atomized_vanillin/'
data = import_SASS(path, '', -1, 2, 0)
dict_keys = ['VANILIN_0.001mM_1.SASS', 'VANILIN_0.001mM_DRY1.SASS', 'VANILIN_0.01mM_1.SASS', 'VANILIN_0.01mM_2.SASS', 'VANILIN_0.01mM_DRY1.SASS']

for key in dict_keys:
    print(key)
    plot_SASS([data[key]], None, 5, ['number'], key)
# Out:
# VANILIN_0.001mM_1.SASS
# VANILIN_0.001mM_DRY1.SASS
# VANILIN_0.01mM_1.SASS
# VANILIN_0.01mM_2.SASS
# VANILIN_0.01mM_DRY1.SASS
